# %%
import cv2
import numpy as np,sys
import matplotlib.pyplot as plt
import os

curpath = os.getcwd()
img = f'{curpath}//task3//ghoul.jpg'
ghoul = cv2.cvtColor(cv2.imread(img), cv2.COLOR_RGB2LAB)
L, A, B = cv2.split(ghoul)
histL = cv2.calcHist([ghoul],[0],None,[256],[0,256])
fig = plt.figure(figsize=(20, 20))
fig.add_subplot(2, 1, 1)
plt.imshow(cv2.imread(img))
fig.add_subplot(2, 1, 2)
plt.plot(histL)
plt.show()

# %%
ghoul = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(ghoul)
plt.imshow(cv2.cvtColor(cl1, cv2.IMREAD_GRAYSCALE))
plt.show()

# %%
list_of_blurs = []
for i in range(0, 3):
    list_of_blurs.append(cv2.cvtColor(cv2.blur(ghoul, (np.random.random_integers(5, 40),np.random.random_integers(5, 40) )), cv2.IMREAD_GRAYSCALE))
columns = 3
fig = plt.figure(figsize=(20, 20))
j = 1
for i in list_of_blurs:
    fig.add_subplot(rows, columns, j)
    j+=1
    plt.imshow(i)
plt.show()
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_8220\1408019700.py:3: DeprecationWarning: This function is deprecated. Please call randint(5, 40 + 1) instead
#   list_of_blurs.append(cv2.cvtColor(cv2.blur(ghoul, (np.random.random_integers(5, 40),np.random.random_integers(5, 40) )), cv2.IMREAD_GRAYSCALE))

# %%
list_of_gaussian_blurs = []
for i in range(0, 3):
        list_of_gaussian_blurs.append(cv2.cvtColor(cv2.GaussianBlur(ghoul, ((2 * np.random.random_integers(5, 40) + 1) , (2 * np.random.random_integers(5, 40) + 1)), 0), cv2.IMREAD_GRAYSCALE))
columns = 3
fig = plt.figure(figsize=(20, 20))
j = 1
for i in list_of_gaussian_blurs:
    fig.add_subplot(rows, columns, j)
    j+=1
    plt.imshow(i)
plt.show()
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_8220\1780122748.py:3: DeprecationWarning: This function is deprecated. Please call randint(5, 40 + 1) instead
#   list_of_gaussian_blurs.append(cv2.cvtColor(cv2.GaussianBlur(lab_image, ((2 * np.random.random_integers(5, 40) + 1) , (2 * np.random.random_integers(5, 40) + 1)), 0), cv2.IMREAD_GRAYSCALE))

# %%
list_of_median = []
for i in range(0, 3):
        list_of_median.append(cv2.cvtColor(cv2.medianBlur(ghoul, 2 * np.random.random_integers(5, 25) + 1), cv2.IMREAD_GRAYSCALE))
columns = 3
fig = plt.figure(figsize=(20, 20))
j = 1
for i in list_of_median:
    fig.add_subplot(rows, columns, j)
    j+=1
    plt.imshow(i)
plt.show()
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_8220\2134179024.py:3: DeprecationWarning: This function is deprecated. Please call randint(5, 25 + 1) instead
#   list_of_median.append(cv2.cvtColor(cv2.medianBlur(lab_image, 2 * np.random.random_integers(5, 25) + 1), cv2.IMREAD_GRAYSCALE))

# %%
list_of_bilaterial = []
for i in range(0, 3):
        list_of_bilaterial.append(cv2.cvtColor(cv2.bilateralFilter(ghoul, 2 * np.random.random_integers(5, 20) + 1, np.random.random_integers(20, 100), np.random.random_integers(20, 100)), cv2.IMREAD_GRAYSCALE))
columns = 3
fig = plt.figure(figsize=(20, 20))
j = 1
for i in list_of_bilaterial:
    fig.add_subplot(rows, columns, j)
    j+=1
    plt.imshow(i)
plt.show()
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_8220\3759792491.py:3: DeprecationWarning: This function is deprecated. Please call randint(5, 20 + 1) instead
#   list_of_bilaterial.append(cv2.cvtColor(cv2.bilateralFilter(ghoul, 2 * np.random.random_integers(5, 20) + 1, np.random.random_integers(20, 100), np.random.random_integers(20, 100)), cv2.IMREAD_GRAYSCALE))
# C:\Users\Egor\AppData\Local\Temp\ipykernel_8220\3759792491.py:3: DeprecationWarning: This function is deprecated. Please call randint(20, 100 + 1) instead
#   list_of_bilaterial.append(cv2.cvtColor(cv2.bilateralFilter(ghoul, 2 * np.random.random_integers(5, 20) + 1, np.random.random_integers(20, 100), np.random.random_integers(20, 100)), cv2.IMREAD_GRAYSCALE))

# %%
list_of_sobel = []
list_of_sobel.append(cv2.cvtColor(cv2.Sobel(ghoul, 0, 0, 1), cv2.IMREAD_GRAYSCALE))
list_of_sobel.append(cv2.cvtColor(cv2.Sobel(ghoul, 0, 1, 0), cv2.IMREAD_GRAYSCALE))
list_of_sobel.append(cv2.cvtColor(cv2.Sobel(ghoul, 0, 1, 1), cv2.IMREAD_GRAYSCALE))
columns = 3
fig = plt.figure(figsize=(20, 20))
j = 1
for i in list_of_sobel:
    fig.add_subplot(rows, columns, j)
    j+=1
    plt.imshow(i)
plt.show()
