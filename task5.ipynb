# %%
import os 
import cv2 
import matplotlib.pyplot as plt

# %%
cv2_dir = os.path.dirname(os.path.abspath(cv2.__file__))
print(cv2_dir)
haar_def = os.path.join(cv2_dir, 'data\haarcascade_frontalface_default.xml')
haar_eye = os.path.join(cv2_dir, 'data\haarcascade_eye.xml')
haar_smile = os.path.join(cv2_dir, 'data\haarcascade_smile.xml')
curpath = os.getcwd()
#print(curpath)
path = f'{curpath}//task5//people.jpg'
img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# c:\Users\Egor\AppData\Local\Programs\Python\Python311\Lib\site-packages\cv2

# %%
cascade = cv2.CascadeClassifier(haar_eye)
rect = cascade.detectMultiScale(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY), scaleFactor=1.05, minNeighbors=1)
res_img = img.copy()
for (x, y, w, h) in rect:
    cv2.rectangle(res_img, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(res_img)
plt.show()

# %%
cascade = cv2.CascadeClassifier(haar_smile)
rect = cascade.detectMultiScale(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY), scaleFactor=4.0, minNeighbors=8)
res_img = img.copy()
for (x, y, w, h) in rect:
    cv2.rectangle(res_img, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(res_img)
plt.show()

# %%
face_cascade = cv2.CascadeClassifier(haar_def)
faces_rect = face_cascade.detectMultiScale(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY), scaleFactor=1.1, minNeighbors=7)
res_img = img.copy()
for (x, y, w, h) in faces_rect:
    cv2.rectangle(res_img, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(res_img)
plt.show()
